# %% [markdown]
# # Let's go PRO!
#
# Advanced RAG Techniques!
#
# Let's start by digging into ingest:
#
# 1. No LangChain! Just native for maximum flexibility
# 2. Let's use an LLM to divide up chunks in a sensible way
# 3. Let's use the best chunk size and encoder from yesterday
# 4. Let's also have the LLM rewrite chunks in a way that's most useful ("document pre-processing")

# %%
# !pip install litellm chromadb tqdm sentence-transformers

from pathlib import Path
import os
from dotenv import load_dotenv
from pydantic import BaseModel, Field
from chromadb import PersistentClient
from tqdm import tqdm
from litellm import completion, acompletion
import asyncio

# Load env
load_dotenv(override=True)

# -------- MODEL ----------
# NVIDIA NIM (correct)
MODEL = "nvidia_nim/meta/llama3-8b-instruct"

# -------- PATHS ----------
DB_NAME = "preprocessed_db"
collection_name = "docs"
KNOWLEDGE_BASE_PATH = Path("knowledge-base")

AVERAGE_CHUNK_SIZE = 400

# Test that NVIDIA key is present
print("NVIDIA_API_KEY found:", bool(os.getenv("NVIDIA_API_KEY")))
# Out:
# Requirement already satisfied: litellm in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (1.80.5)
# Requirement already satisfied: chromadb in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (1.3.5)
# Requirement already satisfied: tqdm in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (4.67.1)
# Requirement already satisfied: sentence-transformers in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (5.1.1)
# Requirement already satisfied: aiohttp>=3.10 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (3.12.15)
# Requirement already satisfied: click in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (8.2.1)
# Requirement already satisfied: fastuuid>=0.13.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (0.14.0)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (8.4.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (4.25.1)
# Requirement already satisfied: openai>=2.8.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (2.8.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (2.12.4)
# Requirement already satisfied: python-dotenv>=0.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (1.1.1)
# Requirement already satisfied: tiktoken>=0.7.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (0.11.0)
# Requirement already satisfied: tokenizers in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from litellm) (0.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from jinja2<4.0.0,>=3.1.2->litellm) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from jsonschema<5.0.0,>=4.22.0->litellm) (0.27.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from pydantic<3.0.0,>=2.5.0->litellm) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (1.73.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (0.17.4)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (4.56.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (2.8.0+cpu)
# Requirement already satisfied: scikit-learn in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (0.35.0)
# Requirement already satisfied: Pillow in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: filelock in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from aiohttp>=3.10->litellm) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from aiohttp>=3.10->litellm) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from aiohttp>=3.10->litellm) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from aiohttp>=3.10->litellm) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from aiohttp>=3.10->litellm) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from aiohttp>=3.10->litellm) (1.20.1)
# Requirement already satisfied: pyproject_hooks in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from httpx>=0.23.0->litellm) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from httpx>=0.23.0->litellm) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->litellm) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from importlib-metadata>=6.8.0->litellm) (3.23.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.2)
# Requirement already satisfied: sympy in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from openai>=2.8.0->litellm) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from openai>=2.8.0->litellm) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.17.3)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.48b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ayush\appdata\local\anaconda3\envs\llms\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# NVIDIA_API_KEY found: True

# %%
# A class similar to LangChain's Result
class Result(BaseModel):
    page_content: str
    metadata: dict


# Chunk model (fixed: added metadata)
class Chunk(BaseModel):
    headline: str
    summary: str
    original_text: str
    metadata: dict = {}  # <-- Added


class Chunks(BaseModel):
    chunks: list[Chunk]

# %%
def fetch_documents():
    documents = []

    for folder in KNOWLEDGE_BASE_PATH.iterdir():
        doc_type = folder.name
        for file in folder.rglob("*.md"):
            with open(file, "r", encoding="utf-8") as f:
                documents.append({
                    "type": doc_type,
                    "source": file.as_posix(),
                    "text": f.read()
                })

    print(f"Loaded {len(documents)} documents")
    return documents


documents = fetch_documents()
# Out:
# Loaded 30 documents

# %%
def make_prompt(document):
    how_many = (len(document["text"]) // AVERAGE_CHUNK_SIZE) + 1

    return f"""
Split the following document into clean, overlapping chunks.

Document Type: {document["type"]}
Source: {document["source"]}

Rules:
- Do NOT leave out any content.
- Use ~{how_many} chunks (flexible).
- Add ~25% overlap (50 words).
- Keep chunk text unchanged.
- Output only JSON.

Document:
{document["text"]}

Output only valid JSON.
"""

# %% [markdown]
# ## Three steps:
#
# 1. Fetch documents from the knowledge base, like LangChain did
# 2. Call an LLM to turn documents into Chunks
# 3. Store the Chunks in Chroma
#
# That's it!
#
# ### Let's start with Step 1

# %%
def make_messages(document):
    return [
        {
            "role": "system",
            "content": """
You MUST respond ONLY with this JSON format:

{
  "chunks": [
    {
      "headline": "...",
      "summary": "...",
      "original_text": "..."
    }
  ]
}

NO extra text. NO explanations.
"""
        },
        {"role": "user", "content": make_prompt(document)}
    ]

# %%
async def process_document_async(document):
    MAX_RETRIES = 5

    for attempt in range(1, MAX_RETRIES + 1):
        try:
            response = await acompletion(
                model=MODEL,
                messages=make_messages(document)
            )

            reply = response.choices[0].message.content

            # Parse JSON
            parsed = Chunks.model_validate_json(reply).chunks

            # Attach metadata
            for c in parsed:
                c.metadata = {
                    "source": document["source"],
                    "type": document["type"]
                }

            return parsed

        except Exception as e:
            print(f"[Retry {attempt}/{MAX_RETRIES}] Error → {e}")
            await asyncio.sleep(attempt * 2)

    raise RuntimeError(f"Failed after {MAX_RETRIES} retries → {document['source']}")

# %% [markdown]
# ### Donezo! On to Step 2 - make the chunks

# %%
async def create_chunks_parallel(documents):
    all_chunks = []

    for doc in tqdm(documents, desc="Processing documents", unit="doc"):
        chunks = await process_document_async(doc)
        all_chunks.extend(chunks)

    return all_chunks


# Run processing
chunks = await create_chunks_parallel(documents)

print("Total chunks created:", len(chunks))
chunks[:2]
# Out:
# Processing documents: 100%|██████████| 30/30 [01:24<00:00,  2.83s/doc]
# Total chunks created: 127
# [Chunk(headline='Professional Bio', summary='Dedicated Computer Science Engineering student with strong analytical mindset and passion for technology.', original_text='Ayush Tyagi is a dedicated Computer Science Engineering student at JIMS, Greater Noida (IP University), on track to graduate in 2025. With a strong foundation built during his PCM schooling at Vivekanand School, Anand Vihar, he has channeled his analytical mindset into a passion for technology. Ayush thrives on the creative process of front-end development, specializing in building visually stunning, user-friendly, and innovative web applications.', metadata={'source': 'knowledge-base/about/bio.md', 'type': 'about'}),
#  Chunk(headline='Unique Combination', summary='Creative eye and logical, problem-solving mindset with a natural strength for designing intuitive and engaging interfaces.', original_text="My uniqueness lies in the powerful combination of a creative eye and a logical, problem-solving mindset. I don't just write code; I craft experiences. I have a natural strength for designing interfaces that are not only aesthetically amazing but also intuitive and engaging.", metadata={'source': 'knowledge-base/about/bio.md', 'type': 'about'})]

# %%
from sentence_transformers import SentenceTransformer

# local embedding model
embedder = SentenceTransformer("all-MiniLM-L6-v2")


def create_embeddings(chunks):
    chroma = PersistentClient(path=DB_NAME)

    # Delete old collection
    if collection_name in [c.name for c in chroma.list_collections()]:
        chroma.delete_collection(collection_name)

    # Prepare data
    texts = [
        chunk.headline + "\n\n" + chunk.summary + "\n\n" + chunk.original_text
        for chunk in chunks
    ]
    metas = [chunk.metadata for chunk in chunks]
    ids = [str(i) for i in range(len(chunks))]

    print("Generating embeddings locally...")

    vectors = embedder.encode(texts, convert_to_numpy=True)

    # Add to Chroma
    collection = chroma.get_or_create_collection(collection_name)
    collection.add(
        ids=ids,
        embeddings=vectors.tolist(),
        documents=texts,
        metadatas=metas
    )

    print(f"Vectorstore created with {collection.count()} documents")

# %%
create_embeddings(chunks)
# Out:
# Generating embeddings locally...
# Vectorstore created with 127 documents

# %%
import numpy as np

# Load Chroma and retrieve stored vectors
chroma = PersistentClient(path=DB_NAME)
collection = chroma.get_or_create_collection(collection_name)

result = collection.get(include=["embeddings", "documents", "metadatas"])

# Extract values
vectors = np.array(result["embeddings"])
documents = result["documents"]
metadatas = result["metadatas"]

# Extract document types from metadata
doc_types = [meta.get("type", "unknown") for meta in metadatas]

# Assign colors for visualization
unique_types = list(sorted(set(doc_types)))

# generate a color map automatically for ANY number of folders
color_palette = [
    "blue", "green", "red", "orange", 
    "purple", "cyan", "pink", "yellow",
    "brown", "gray"
]

# map each folder type to a unique color
type_to_color = {
    doc_type: color_palette[i % len(color_palette)]
    for i, doc_type in enumerate(unique_types)
}

# final colors list per document
colors = [type_to_color[t] for t in doc_types]

print("Found document types:", unique_types)
print("Color map:", type_to_color)
# Out:
# Found document types: ['about', 'education', 'experience', 'extras', 'projects', 'skills']
# Color map: {'about': 'blue', 'education': 'green', 'experience': 'red', 'extras': 'orange', 'projects': 'purple', 'skills': 'cyan'}

# %%
from sklearn.manifold import TSNE
import plotly.graph_objects as go
import numpy as np

# --- SAFETY: If vectors are large, reduce perplexity ---
perplexity = min(30, len(vectors) - 1)

tsne = TSNE(
    n_components=2,
    random_state=42,
    perplexity=perplexity,
    learning_rate="auto",
    init="pca"
)

reduced_vectors = tsne.fit_transform(vectors)

# --- HOVER TEXT (shortened for speed) ---
hover_texts = [
    f"<b>Type:</b> {t}<br><b>Source:</b> {m.get('source','')}<br><br>{d[:150]}..."
    for t, m, d in zip(doc_types, metadatas, documents)
]

# --- PLOT ---
fig = go.Figure(data=[
    go.Scatter(
        x=reduced_vectors[:, 0],
        y=reduced_vectors[:, 1],
        mode='markers',
        marker=dict(
            size=6,
            color=colors,
            opacity=0.8,
            line=dict(width=0.5, color="black")
        ),
        text=hover_texts,
        hoverinfo='text'
    )
])

fig.update_layout(
    title="📌 2D Vector Store t-SNE Visualization",
    xaxis_title="t-SNE dimension 1",
    yaxis_title="t-SNE dimension 2",
    width=900,
    height=700,
    margin=dict(l=20, r=20, t=60, b=20),
    template="plotly_dark"
)

fig.show()

# %%
from sklearn.manifold import TSNE
import plotly.graph_objects as go
import numpy as np

# --- SAFETY FIX: perplexity must be < num_samples ---
perplexity = min(30, len(vectors) - 1)

# --- 3D TSNE ---
tsne = TSNE(
    n_components=3,
    random_state=42,
    perplexity=perplexity,
    init="pca",
    learning_rate="auto"
)

reduced_vectors = tsne.fit_transform(vectors)

# --- Hover text with type + preview ---
hover_texts = [
    f"<b>Type:</b> {t}<br><b>Source:</b> {m.get('source','')}<br><br>{d[:150]}..."
    for t, m, d in zip(doc_types, metadatas, documents)
]

# --- 3D Scatter Plot ---
fig = go.Figure(data=[
    go.Scatter3d(
        x=reduced_vectors[:, 0],
        y=reduced_vectors[:, 1],
        z=reduced_vectors[:, 2],
        mode='markers',
        marker=dict(
            size=6,
            color=colors,
            opacity=0.85,
            line=dict(width=0.5, color="black")
        ),
        text=hover_texts,
        hoverinfo='text'
    )
])

fig.update_layout(
    title="🌌 3D t-SNE Visualization of Ayush’s Vector Database",
    scene=dict(
        xaxis_title="t-SNE Dim 1",
        yaxis_title="t-SNE Dim 2",
        zaxis_title="t-SNE Dim 3",
    ),
    width=950,
    height=750,
    template="plotly_dark",
    margin=dict(l=10, r=10, t=60, b=10)
)

fig.show()

# %% [markdown]
# ### Well that was easy! If a bit slow.
#
# In the python module version, I sneakily use the multi-processing Pool to run this in parallel,
# but if you get a Rate Limit Error you can turn this off in the code.
#
# ### Finally, Step 3 - save the embeddings

# %% [markdown]
# # Nothing more to do here... right?
#
# Wait! Didja think I'd forget??

# %% [markdown]
# ## And now - let's build an Advanced RAG!
#
# We will use these techniques:
#
# 1. Reranking - reorder the rank results
# 2. Query re-writing

# %%
class RankOrder(BaseModel):
    order: list[int] = Field(
        description="The order of relevance of chunks, from most relevant to least relevant, by chunk id number"
    )

# %%
def rerank(question, chunks):
    system_prompt = """
You are a document re-ranker.
You are provided with a question and a list of relevant chunks of text from a query of a knowledge base.
The chunks are provided in the order they were retrieved; this should be approximately ordered by relevance, but you may be able to improve on that.
You must rank order the provided chunks by relevance to the question, with the most relevant chunk first.
Reply only with the list of ranked chunk ids, nothing else. Include all the chunk ids you are provided with, reranked.
"""
    user_prompt = f"The user has asked the following question:\n\n{question}\n\nOrder all the chunks of text by relevance to the question, from most relevant to least relevant. Include all the chunk ids you are provided with, reranked.\n\n"
    user_prompt += "Here are the chunks:\n\n"
    for index, chunk in enumerate(chunks):
        user_prompt += f"# CHUNK ID: {index + 1}:\n\n{chunk.page_content}\n\n"
    user_prompt += "Reply only with the list of ranked chunk ids, nothing else."
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt},
    ]
    response = completion(model=MODEL, messages=messages, response_format=RankOrder)
    reply = response.choices[0].message.content
    order = RankOrder.model_validate_json(reply).order
    print(order)
    return [chunks[i - 1] for i in order]

# %%
RETRIEVAL_K = 10

def fetch_context_unranked(question):
    query = openai.embeddings.create(model=embedding_model, input=[question]).data[0].embedding
    results = collection.query(query_embeddings=[query], n_results=RETRIEVAL_K)
    chunks = []
    for result in zip(results["documents"][0], results["metadatas"][0]):
        chunks.append(Result(page_content=result[0], metadata=result[1]))
    return chunks

# %%
question = "Who won the IIOTY award?"
chunks = fetch_context_unranked(question)

# %%
for chunk in chunks:
    print(chunk.page_content[:15]+"...")

# %%
reranked = rerank(question, chunks)

# %%
for chunk in reranked:
    print(chunk.page_content[:15]+"...")

# %%
question = "Who went to Manchester University?"
RETRIEVAL_K = 20
chunks = fetch_context_unranked(question)
for index, c in enumerate(chunks):
    if "manchester" in c.page_content.lower():
        print(index)

# %%
reranked = rerank(question, chunks)

# %%
for index, c in enumerate(reranked):
    if "manchester" in c.page_content.lower():
        print(index)

# %%
reranked[0].page_content

# %%
def fetch_context(question):
    chunks = fetch_context_unranked(question)
    return rerank(question, chunks)

# %%
SYSTEM_PROMPT = """
You are a knowledgeable, friendly assistant representing the company Insurellm.
You are chatting with a user about Insurellm.
Your answer will be evaluated for accuracy, relevance and completeness, so make sure it only answers the question and fully answers it.
If you don't know the answer, say so.
For context, here are specific extracts from the Knowledge Base that might be directly relevant to the user's question:
{context}

With this context, please answer the user's question. Be accurate, relevant and complete.
"""

# %%
# In the context, include the source of the chunk

def make_rag_messages(question, history, chunks):
    context = "\n\n".join(f"Extract from {chunk.metadata['source']}:\n{chunk.page_content}" for chunk in chunks)
    system_prompt = SYSTEM_PROMPT.format(context=context)
    return [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": question}]

# %%
def rewrite_query(question, history=[]):
    """Rewrite the user's question to be a more specific question that is more likely to surface relevant content in the Knowledge Base."""
    message = f"""
You are in a conversation with a user, answering questions about the company Insurellm.
You are about to look up information in a Knowledge Base to answer the user's question.

This is the history of your conversation so far with the user:
{history}

And this is the user's current question:
{question}

Respond only with a single, refined question that you will use to search the Knowledge Base.
It should be a VERY short specific question most likely to surface content. Focus on the question details.
Don't mention the company name unless it's a general question about the company.
IMPORTANT: Respond ONLY with the knowledgebase query, nothing else.
"""
    response = completion(model=MODEL, messages=[{"role": "system", "content": message}])
    return response.choices[0].message.content

# %%
rewrite_query("Who won the IIOTY award?", [])

# %%
def answer_question(question: str, history: list[dict] = []) -> tuple[str, list]:
    """
    Answer a question using RAG and return the answer and the retrieved context
    """
    query = rewrite_query(question, history)
    print(query)
    chunks = fetch_context(query)
    messages = make_rag_messages(question, history, chunks)
    response = completion(model=MODEL, messages=messages)
    return response.choices[0].message.content, chunks

# %%
answer_question("Who won the IIOTY award?", [])

# %%
answer_question("Who went to Manchester University?", [])
